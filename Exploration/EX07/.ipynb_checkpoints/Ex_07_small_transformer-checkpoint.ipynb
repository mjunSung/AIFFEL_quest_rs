# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import urllib.request
import time
import tensorflow_datasets as tfds
import tensorflow as tf
# Out:
# 2024-12-03 15:58:56.676303: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Step 1. 데이터 수집하기
# - songys/Chatbot_data

# %%
train = pd.read_csv('/home/mjun/ChatbotData .csv')
train.head()
# Out:
#                  Q            A  label
# 0           12시 땡!   하루가 또 가네요.      0
# 1      1지망 학교 떨어졌어    위로해 드립니다.      0
# 2     3박4일 놀러가고 싶다  여행은 언제나 좋죠.      0
# 3  3박4일 정도 놀러가고 싶다  여행은 언제나 좋죠.      0
# 4          PPL 심하네   눈살이 찌푸려지죠.      0

# %%
print(f'샘플 개수 : {len(train)}')
# Out:
# 샘플 개수 : 11823

# %% [markdown]
# null값 확인

# %%
print(train.isnull().sum())
# Out:
# Q        0
# A        0
# label    0
# dtype: int64

# %% [markdown]
# ## Step 2. 데이터 전처리하기
# - 영어 데이터와는 전혀 다른 데이터인 만큼 영어 데이터에 사용했던 전처리와 일부 동일한 전처리도 필요하겠지만 전체적으로는 다른 전처리를 수행해야 할 수도 있습니다.

# %%
import re

# 사용할 샘플의 최대 개수
MAX_SAMPLES = 11823

# 한글 데이터에 맞는 전처리 함수
def preprocess_sentence(sentence):
    sentence = sentence.lower().strip()
    sentence = re.sub(r"([?.!,])", r" \1 ", sentence)
    sentence = re.sub(r'[" "]+', " ", sentence)
    sentence = sentence.strip()

    return sentence

def load_conversations(questions, answers):
    inputs, outputs = [], []
    
    for question, answer in zip(questions, answers):
        inputs.append(preprocess_sentence(question))
        outputs.append(preprocess_sentence(answer))
        
    return inputs, outputs

# %%
questions, answers = load_conversations(train['Q'], train['A'])
print('전체 샘플 수 :', len(questions))
print('전체 샘플 수 :', len(answers))
# Out:
# 전체 샘플 수 : 11823
# 전체 샘플 수 : 11823

# %%
print(questions[:5])
print(answers[:5])
# Out:
# ['12시 땡 !', '1지망 학교 떨어졌어', '3박4일 놀러가고 싶다', '3박4일 정도 놀러가고 싶다', 'ppl 심하네']
# ['하루가 또 가네요 .', '위로해 드립니다 .', '여행은 언제나 좋죠 .', '여행은 언제나 좋죠 .', '눈살이 찌푸려지죠 .']

# %% [markdown]
# ## Step 3. SubwordTextEncoder 사용하기
# - 한국어 데이터는 형태소 분석기를 사용하여 토크나이징을 해야 한다고 많은 분이 알고 있습니다. 하지만 여기서는 형태소 분석기가 아닌 위 실습에서 사용했던 내부 단어 토크나이저인 SubwordTextEncoder를 그대로 사용해보세요.

# %%
# 서브워드텍스트인코더를 사용하여 질문, 답변 데이터로부터 단어 집합 생성
tokenizer = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    questions + answers, target_vocab_size=2**13)

# %%
# 시작 토큰과 종료 토큰에 대한 정수 부여.
START_TOKEN, END_TOKEN = [tokenizer.vocab_size], [tokenizer.vocab_size + 1]

# 시작 토큰과 종료 토큰을 고려하여 단어 집합의 크기를 + 2
VOCAB_SIZE = tokenizer.vocab_size + 2

# %%
print('시작 토큰 번호 :',START_TOKEN)
print('종료 토큰 번호 :',END_TOKEN)
print('단어 집합의 크기 :',VOCAB_SIZE)
# Out:
# 시작 토큰 번호 : [8173]
# 종료 토큰 번호 : [8174]
# 단어 집합의 크기 : 8175

# %% [markdown]
# 정수 인코딩, 패딩
# - 토크나이저의 .encode()와 .decode() 기능 사용

# %%
# 최대 길이를 40으로 정의
MAX_LENGTH = 40

# %%
# 학습 데이터 정수 인코딩, 패딩 함수 구현
def tokenize_n_filter(inputs, outputs):
    tokenized_inputs, tokenized_outputs = [], []
  
    for (sentence1, sentence2) in zip(inputs, outputs):
        # encode(토큰화 + 정수 인코딩), 시작 토큰과 종료 토큰 추가
        sentence1 = START_TOKEN + tokenizer.encode(sentence1) + END_TOKEN
        sentence2 = START_TOKEN + tokenizer.encode(sentence2) + END_TOKEN

        tokenized_inputs.append(sentence1)
        tokenized_outputs.append(sentence2)

    # 패딩
    tokenized_inputs = tf.keras.preprocessing.sequence.pad_sequences(
        tokenized_inputs, maxlen=MAX_LENGTH, padding='post')
    tokenized_outputs = tf.keras.preprocessing.sequence.pad_sequences(
        tokenized_outputs, maxlen=MAX_LENGTH, padding='post')

    return tokenized_inputs, tokenized_outputs

# %%
questions, answers = tokenize_n_filter(questions, answers)

# %%
print(f'질문 데이터의 크기(shape) : {questions.shape}')
print(f'답변 데이터의 크기(shape) : {answers.shape}')
# Out:
# 질문 데이터의 크기(shape) : (11823, 40)
# 답변 데이터의 크기(shape) : (11823, 40)

# %% [markdown]
# ## Step 4. 모델 구성하기
# - 위 실습 내용을 참고하여 트랜스포머 모델을 구현합니다.
# - 이전 노드에서 구성가져오기

# %%
# 포지셔널 인코딩 레이어
class PositionalEncoding(tf.keras.layers.Layer):

  def __init__(self, position, d_model):
    super(PositionalEncoding, self).__init__()
    self.pos_encoding = self.positional_encoding(position, d_model)

  def get_angles(self, position, i, d_model):
    angles = 1 / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
    return position * angles

  def positional_encoding(self, position, d_model):
    # 각도 배열 생성
    angle_rads = self.get_angles(
        position=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
        i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
        d_model=d_model)

    # 배열의 짝수 인덱스에는 sin 함수 적용
    sines = tf.math.sin(angle_rads[:, 0::2])
    # 배열의 홀수 인덱스에는 cosine 함수 적용
    cosines = tf.math.cos(angle_rads[:, 1::2])

    # sin과 cosine이 교차되도록 재배열
    pos_encoding = tf.stack([sines, cosines], axis=0)
    pos_encoding = tf.transpose(pos_encoding,[1, 2, 0]) 
    pos_encoding = tf.reshape(pos_encoding, [position, d_model])

    pos_encoding = pos_encoding[tf.newaxis, ...]
    return tf.cast(pos_encoding, tf.float32)

  def call(self, inputs):
    return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# %%
# 스케일드 닷 프로덕트 어텐션 함수
def scaled_dot_product_attention(query, key, value, mask):
  # 어텐션 가중치는 Q와 K의 닷 프로덕트
  matmul_qk = tf.matmul(query, key, transpose_b=True)

  # 가중치를 정규화
  depth = tf.cast(tf.shape(key)[-1], tf.float32)
  logits = matmul_qk / tf.math.sqrt(depth)

  # 패딩에 마스크 추가
  if mask is not None:
    logits += (mask * -1e9)

  # softmax적용
  attention_weights = tf.nn.softmax(logits, axis=-1)

  # 최종 어텐션은 가중치와 V의 닷 프로덕트
  output = tf.matmul(attention_weights, value)
  return output

# %%
class MultiHeadAttention(tf.keras.layers.Layer):

  def __init__(self, d_model, num_heads, name="multi_head_attention"):
    super(MultiHeadAttention, self).__init__(name=name)
    self.num_heads = num_heads
    self.d_model = d_model

    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.query_dense = tf.keras.layers.Dense(units=d_model)
    self.key_dense = tf.keras.layers.Dense(units=d_model)
    self.value_dense = tf.keras.layers.Dense(units=d_model)

    self.dense = tf.keras.layers.Dense(units=d_model)

  def split_heads(self, inputs, batch_size):
    inputs = tf.reshape(
        inputs, shape=(batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(inputs, perm=[0, 2, 1, 3])

  def call(self, inputs):
    query, key, value, mask = inputs['query'], inputs['key'], inputs[
        'value'], inputs['mask']
    batch_size = tf.shape(query)[0]

    # Q, K, V에 각각 Dense를 적용합니다
    query = self.query_dense(query)
    key = self.key_dense(key)
    value = self.value_dense(value)

    # 병렬 연산을 위한 머리를 여러 개 만듭니다
    query = self.split_heads(query, batch_size)
    key = self.split_heads(key, batch_size)
    value = self.split_heads(value, batch_size)
    
    # 스케일드 닷 프로덕트 어텐션 함수
    scaled_attention = scaled_dot_product_attention(query, key, value, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])

    # 어텐션 연산 후에 각 결과를 다시 연결(concatenate)합니다
    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))

    # 최종 결과에도 Dense를 한 번 더 적용합니다
    outputs = self.dense(concat_attention)

    return outputs

# %%
# 패딩 마스킹
def create_padding_mask(x):
  mask = tf.cast(tf.math.equal(x, 0), tf.float32)
  # (batch_size, 1, 1, sequence length)
  return mask[:, tf.newaxis, tf.newaxis, :]

# %%
# 룩 어헤드 마스킹(Look-ahead masking, 다음 단어 가리기)
def create_look_ahead_mask(x):
  seq_len = tf.shape(x)[1]
  look_ahead_mask = 1 - tf.linalg.band_part(tf.ones((seq_len, seq_len)), -1, 0)
  padding_mask = create_padding_mask(x)
  return tf.maximum(look_ahead_mask, padding_mask)

# %%
# 인코더 하나의 레이어를 함수로 구현.
# 이 하나의 레이어 안에는 두 개의 서브 레이어가 존재합니다.
def encoder_layer(units, d_model, num_heads, dropout, name="encoder_layer"):
  inputs = tf.keras.Input(shape=(None, d_model), name="inputs")

  # 패딩 마스크 사용
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  # 첫 번째 서브 레이어 : 멀티 헤드 어텐션 수행 (셀프 어텐션)
  attention = MultiHeadAttention(
      d_model, num_heads, name="attention")({
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': padding_mask
      })

  # 어텐션의 결과는 Dropout과 Layer Normalization이라는 훈련을 돕는 테크닉을 수행
  attention = tf.keras.layers.Dropout(rate=dropout)(attention)
  attention = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(inputs + attention)

  # 두 번째 서브 레이어 : 2개의 완전연결층
  outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention)
  outputs = tf.keras.layers.Dense(units=d_model)(outputs)

  # 완전연결층의 결과는 Dropout과 LayerNormalization이라는 훈련을 돕는 테크닉을 수행
  outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
  outputs = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention + outputs)

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
def encoder(vocab_size,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            name="encoder"):
  inputs = tf.keras.Input(shape=(None,), name="inputs")

  # 패딩 마스크 사용
  padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")

  # 임베딩 레이어
  embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
  embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))

  # 포지셔널 인코딩
  embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

  outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

  # num_layers만큼 쌓아올린 인코더의 층.
  for i in range(num_layers):
    outputs = encoder_layer(
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
        name="encoder_layer_{}".format(i),
    )([outputs, padding_mask])

  return tf.keras.Model(
      inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
# 디코더 하나의 레이어를 함수로 구현.
# 이 하나의 레이어 안에는 세 개의 서브 레이어가 존재합니다.
def decoder_layer(units, d_model, num_heads, dropout, name="decoder_layer"):
  inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
  enc_outputs = tf.keras.Input(shape=(None, d_model), name="encoder_outputs")
  look_ahead_mask = tf.keras.Input(
      shape=(1, None, None), name="look_ahead_mask")
  padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')

  # 첫 번째 서브 레이어 : 멀티 헤드 어텐션 수행 (셀프 어텐션)
  attention1 = MultiHeadAttention(
      d_model, num_heads, name="attention_1")(inputs={
          'query': inputs,
          'key': inputs,
          'value': inputs,
          'mask': look_ahead_mask
      })

  # 멀티 헤드 어텐션의 결과는 LayerNormalization이라는 훈련을 돕는 테크닉을 수행
  attention1 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention1 + inputs)

  # 두 번째 서브 레이어 : 마스크드 멀티 헤드 어텐션 수행 (인코더-디코더 어텐션)
  attention2 = MultiHeadAttention(
      d_model, num_heads, name="attention_2")(inputs={
          'query': attention1,
          'key': enc_outputs,
          'value': enc_outputs,
          'mask': padding_mask
      })

  # 마스크드 멀티 헤드 어텐션의 결과는
  # Dropout과 LayerNormalization이라는 훈련을 돕는 테크닉을 수행
  attention2 = tf.keras.layers.Dropout(rate=dropout)(attention2)
  attention2 = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(attention2 + attention1)

  # 세 번째 서브 레이어 : 2개의 완전연결층
  outputs = tf.keras.layers.Dense(units=units, activation='relu')(attention2)
  outputs = tf.keras.layers.Dense(units=d_model)(outputs)

  # 완전연결층의 결과는 Dropout과 LayerNormalization 수행
  outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
  outputs = tf.keras.layers.LayerNormalization(
      epsilon=1e-6)(outputs + attention2)

  return tf.keras.Model(
      inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
      outputs=outputs,
      name=name)

# %%
def decoder(vocab_size,
            num_layers,
            units,
            d_model,
            num_heads,
            dropout,
            name='decoder'):
  inputs = tf.keras.Input(shape=(None,), name='inputs')
  enc_outputs = tf.keras.Input(shape=(None, d_model), name='encoder_outputs')
  look_ahead_mask = tf.keras.Input(
      shape=(1, None, None), name='look_ahead_mask')

  # 패딩 마스크
  padding_mask = tf.keras.Input(shape=(1, 1, None), name='padding_mask')
  
  # 임베딩 레이어
  embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
  embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))

  # 포지셔널 인코딩
  embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)

  # Dropout이라는 훈련을 돕는 테크닉을 수행
  outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)

  for i in range(num_layers):
    outputs = decoder_layer(
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
        name='decoder_layer_{}'.format(i),
    )(inputs=[outputs, enc_outputs, look_ahead_mask, padding_mask])

  return tf.keras.Model(
      inputs=[inputs, enc_outputs, look_ahead_mask, padding_mask],
      outputs=outputs,
      name=name)

# %% [markdown]
# ## Step 5. 모델 평가하기
# - Step 1에서 선택한 전처리 방법을 고려하여 입력된 문장에 대해서 대답을 얻는 예측 함수를 만듭니다.

# %%
BATCH_SIZE = 64
BUFFER_SIZE = 20000

dataset = tf.data.Dataset.from_tensor_slices((
    {
        'inputs': questions,
        'dec_inputs': answers[:, :-1]
    },
    {
        'outputs': answers[:, 1:]
    },
))

dataset = dataset.cache()
dataset = dataset.shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE)
dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
# Out:
# 2024-12-03 15:59:10.734689: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9621 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:19:00.0, compute capability: 7.5
# 2024-12-03 15:59:10.735378: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9621 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# 2024-12-03 15:59:10.735814: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9621 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:67:00.0, compute capability: 7.5
# 2024-12-03 15:59:10.736389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 9604 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:68:00.0, compute capability: 7.5

# %%
def transformer(vocab_size,
                num_layers,
                units,
                d_model,
                num_heads,
                dropout,
                name="transformer"):
    inputs = tf.keras.Input(shape=(None,), name="inputs")
    dec_inputs = tf.keras.Input(shape=(None,), name="dec_inputs")

    enc_padding_mask = tf.keras.layers.Lambda(
        create_padding_mask, output_shape=(1, 1, None),
        name='enc_padding_mask')(inputs)

    look_ahead_mask = tf.keras.layers.Lambda(
        create_look_ahead_mask,
        output_shape=(1, None, None),
        name='look_ahead_mask')(dec_inputs)

    dec_padding_mask = tf.keras.layers.Lambda(
        create_padding_mask, output_shape=(1, 1, None),
        name='dec_padding_mask')(inputs)

    # encoder
    enc_outputs = encoder(
        vocab_size=vocab_size,
        num_layers=num_layers,
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
    )(inputs=[inputs, enc_padding_mask])

    # decoder
    dec_outputs = decoder(
        vocab_size=vocab_size,
        num_layers=num_layers,
        units=units,
        d_model=d_model,
        num_heads=num_heads,
        dropout=dropout,
    )(inputs=[dec_inputs, enc_outputs, look_ahead_mask, dec_padding_mask])

    outputs = tf.keras.layers.Dense(
        units=vocab_size, name="outputs")(dec_outputs)

    return tf.keras.Model(inputs=[inputs, dec_inputs], outputs=outputs, name=name)

# %%
tf.keras.backend.clear_session()

NUM_LAYERS = 2  # 인코더와 디코더의 층의 개수
D_MODEL = 256  # 인코더와 디코더 내부의 입, 출력의 고정 차원
NUM_HEADS = 8  # 멀티 헤드 어텐션에서의 헤드 수
UNITS = 512  # 피드 포워드 신경망의 은닉층의 크기
DROPOUT = 0.1  # 드롭아웃의 비율

model = transformer(
    vocab_size=VOCAB_SIZE,
    num_layers=NUM_LAYERS,
    units=UNITS,
    d_model=D_MODEL,
    num_heads=NUM_HEADS,
    dropout=DROPOUT)

model.summary()
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  inputs (InputLayer)         [(None, None)]               0         []
#
#  dec_inputs (InputLayer)     [(None, None)]               0         []
#
#  enc_padding_mask (Lambda)   (None, 1, 1, None)           0         ['inputs[0][0]']
#
#  encoder (Functional)        (None, None, 256)            3147008   ['inputs[0][0]',
#                                                                      'enc_padding_mask[0][0]']
#
#  look_ahead_mask (Lambda)    (None, 1, None, None)        0         ['dec_inputs[0][0]']
#
#  dec_padding_mask (Lambda)   (None, 1, 1, None)           0         ['inputs[0][0]']
#
#  decoder (Functional)        (None, None, 256)            3674368   ['dec_inputs[0][0]',
#                                                                      'encoder[0][0]',
#                                                                      'look_ahead_mask[0][0]',
#                                                                      'dec_padding_mask[0][0]']
#
#  outputs (Dense)             (None, None, 8175)           2100975   ['decoder[0][0]']
#
# ==================================================================================================
# Total params: 8922351 (34.04 MB)
# Trainable params: 8922351 (34.04 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# def loss_function(y_true, y_pred):
#     y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))

#     loss = tf.keras.losses.SparseCategoricalCrossentropy(
#         from_logits=True, reduction='none')(y_true, y_pred)

#     mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)
#     loss = tf.multiply(loss, mask)

#     return tf.reduce_mean(loss)

@tf.function
def loss_function(y_true, y_pred):
    y_true = tf.reshape(y_true, shape=(-1, MAX_LENGTH - 1))
    y_pred = y_pred[:, :tf.shape(y_true)[1], :]  # y_true 길이에 맞추기

    loss = tf.keras.losses.SparseCategoricalCrossentropy(
        from_logits=True, reduction='none')(y_true, y_pred)

    mask = tf.cast(tf.not_equal(y_true, 0), tf.float32)
    loss = tf.multiply(loss, mask)

    return tf.reduce_mean(loss)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):

  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()
    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)
    self.warmup_steps = warmup_steps

  def __call__(self, step):
    step = tf.cast(step, tf.float32)
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps**-1.5)

    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)
  
  def get_config(self):
    return {
          "d_model": self.d_model.numpy(),  # 텐서를 numpy 값으로 변환
          "warmup_steps": self.warmup_steps
        }

# %%
# val_loss 구하기 위해, 데이터 셋 분리
from sklearn.model_selection import train_test_split

# 데이터셋 분리 (80% 학습, 20% 검증)
X_train, X_val, y_train, y_val = train_test_split(
    questions, answers, test_size=0.2, random_state=42
)

from tensorflow.keras.preprocessing.sequence import pad_sequences

# 패딩 처리
X_train = pad_sequences(X_train, maxlen=MAX_LENGTH, padding='post')
X_val = pad_sequences(X_val, maxlen=MAX_LENGTH, padding='post')
y_train = pad_sequences(y_train, maxlen=MAX_LENGTH, padding='post')
y_val = pad_sequences(y_val, maxlen=MAX_LENGTH, padding='post')

# 학습 데이터셋
train_dataset = tf.data.Dataset.from_tensor_slices((
    {
        'inputs': X_train,           # 입력 데이터
        'dec_inputs': y_train[:, :-1]  # 디코더 입력 (마지막 토큰 제외)
    },
    {
        'outputs': y_train[:, 1:]      # 디코더 출력 (첫 번째 토큰 제외)
    }
)).batch(BATCH_SIZE)

# 검증 데이터셋
val_dataset = tf.data.Dataset.from_tensor_slices((
    {
        'inputs': X_val,            # 입력 데이터
        'dec_inputs': y_val[:, :-1]   # 디코더 입력 (마지막 토큰 제외)
    },
    {
        'outputs': y_val[:, 1:]       # 디코더 출력 (첫 번째 토큰 제외)
    }
)).batch(BATCH_SIZE)

# %%
import os
learning_rate = CustomSchedule(D_MODEL)

optimizer = tf.keras.optimizers.Adam(
    learning_rate, beta_1=0.9, beta_2=0.98, epsilon=1e-9)

# 체크포인트 디렉토리 설정
checkpoint_dir = './checkpoints/val_loss/small'
os.makedirs(checkpoint_dir, exist_ok=True)
    
# dataset_size = len(dataset)  # 데이터셋 크기를 직접 확인하거나 지정
# steps_per_epoch = dataset_size // BATCH_SIZE

# 체크포인트 콜백 설정
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=os.path.join(checkpoint_dir, 'model_epoch_{epoch:02d}.ckpt'),
    save_weights_only = True,
    monitor = 'val_loss',
    mode = 'auto',
    save_best_only = True
)


@tf.function
def accuracy(y_true, y_pred):
    # y_pred의 시퀀스 길이를 y_true에 맞춤
    y_pred = y_pred[:, :tf.shape(y_true)[1], :]  # y_true의 길이에 맞춤

    # y_pred에서 가장 높은 확률을 가진 인덱스 선택
    y_pred = tf.argmax(y_pred, axis=-1)  # (batch_size, sequence_length)

    # y_true와 y_pred를 동일한 데이터 타입으로 변환
    y_true = tf.cast(y_true, dtype=tf.int32)
    y_pred = tf.cast(y_pred, dtype=tf.int32)

    # y_true와 y_pred를 1차원으로 변환
    y_true = tf.reshape(y_true, shape=(-1,))
    y_pred = tf.reshape(y_pred, shape=(-1,))

    # y_true와 y_pred가 동일한지 비교
    matches = tf.cast(tf.equal(y_true, y_pred), tf.float32)

    # 정확도 계산
    return tf.reduce_mean(matches)


model.compile(optimizer=optimizer, loss=loss_function, metrics=[accuracy])

# %%
EPOCHS = 30

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    callbacks=[checkpoint_callback],
    verbose=1
)
# Out:
# Epoch 1/30
# 2024-12-03 15:59:20.878741: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7ff2d0a50a90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-12-03 15:59:20.878777: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2024-12-03 15:59:20.878785: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2024-12-03 15:59:20.878792: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2024-12-03 15:59:20.878798: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (3): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2024-12-03 15:59:20.883744: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-12-03 15:59:23.191014: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8801
# 2024-12-03 15:59:23.606246: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 148/148 [==============================] - 58s 277ms/step - loss: 1.4851 - accuracy: 0.0217 - val_loss: 1.3855 - val_accuracy: 0.0384
# Epoch 2/30
# 148/148 [==============================] - 8s 56ms/step - loss: 1.2572 - accuracy: 0.0484 - val_loss: 1.1548 - val_accuracy: 0.0499
# Epoch 3/30
# 148/148 [==============================] - 8s 56ms/step - loss: 1.0644 - accuracy: 0.0498 - val_loss: 1.0261 - val_accuracy: 0.0501
# Epoch 4/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.9691 - accuracy: 0.0514 - val_loss: 0.9704 - val_accuracy: 0.0534
# Epoch 5/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.9142 - accuracy: 0.0548 - val_loss: 0.9318 - val_accuracy: 0.0555
# Epoch 6/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.8646 - accuracy: 0.0574 - val_loss: 0.8973 - val_accuracy: 0.0585
# Epoch 7/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.8142 - accuracy: 0.0606 - val_loss: 0.8705 - val_accuracy: 0.0609
# Epoch 8/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.7592 - accuracy: 0.0656 - val_loss: 0.8417 - val_accuracy: 0.0644
# Epoch 9/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.6973 - accuracy: 0.0720 - val_loss: 0.8099 - val_accuracy: 0.0682
# Epoch 10/30
# 148/148 [==============================] - 8s 55ms/step - loss: 0.6324 - accuracy: 0.0790 - val_loss: 0.7810 - val_accuracy: 0.0712
# Epoch 11/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.5662 - accuracy: 0.0866 - val_loss: 0.7640 - val_accuracy: 0.0737
# Epoch 12/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.4964 - accuracy: 0.0949 - val_loss: 0.7500 - val_accuracy: 0.0753
# Epoch 13/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.4238 - accuracy: 0.1043 - val_loss: 0.7386 - val_accuracy: 0.0776
# Epoch 14/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.3539 - accuracy: 0.1139 - val_loss: 0.7336 - val_accuracy: 0.0802
# Epoch 15/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.2859 - accuracy: 0.1238 - val_loss: 0.7267 - val_accuracy: 0.0830
# Epoch 16/30
# 148/148 [==============================] - 8s 56ms/step - loss: 0.2276 - accuracy: 0.1334 - val_loss: 0.7243 - val_accuracy: 0.0862
# Epoch 17/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.1764 - accuracy: 0.1421 - val_loss: 0.7271 - val_accuracy: 0.0898
# Epoch 18/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.1318 - accuracy: 0.1505 - val_loss: 0.7468 - val_accuracy: 0.0913
# Epoch 19/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.0958 - accuracy: 0.1570 - val_loss: 0.7594 - val_accuracy: 0.0929
# Epoch 20/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.0713 - accuracy: 0.1612 - val_loss: 0.7949 - val_accuracy: 0.0924
# Epoch 21/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.0536 - accuracy: 0.1642 - val_loss: 0.8136 - val_accuracy: 0.0939
# Epoch 22/30
# 148/148 [==============================] - 8s 55ms/step - loss: 0.0430 - accuracy: 0.1658 - val_loss: 0.8422 - val_accuracy: 0.0943
# Epoch 23/30
# 148/148 [==============================] - 8s 55ms/step - loss: 0.0373 - accuracy: 0.1666 - val_loss: 0.8678 - val_accuracy: 0.0939
# Epoch 24/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.0340 - accuracy: 0.1668 - val_loss: 0.8810 - val_accuracy: 0.0953
# Epoch 25/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.0308 - accuracy: 0.1674 - val_loss: 0.8960 - val_accuracy: 0.0946
# Epoch 26/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.0282 - accuracy: 0.1678 - val_loss: 0.9150 - val_accuracy: 0.0952
# Epoch 27/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.0280 - accuracy: 0.1676 - val_loss: 0.9319 - val_accuracy: 0.0949
# Epoch 28/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.0269 - accuracy: 0.1679 - val_loss: 0.9428 - val_accuracy: 0.0944
# Epoch 29/30
# 148/148 [==============================] - 8s 55ms/step - loss: 0.0250 - accuracy: 0.1684 - val_loss: 0.9524 - val_accuracy: 0.0949
# Epoch 30/30
# 148/148 [==============================] - 8s 54ms/step - loss: 0.0223 - accuracy: 0.1690 - val_loss: 0.9568 - val_accuracy: 0.0955

# %%
# loss 시각화
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# accuracy 시각화
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# 마천가지로 overfitting 보이고 16 ~ 17 에폭에서 끝남

# %% [markdown]
# ## Inference

# %%
# 테스트
def decoder_inference(sentence):
  sentence = preprocess_sentence(sentence)

  # 입력된 문장을 정수 인코딩 후, 시작 토큰과 종료 토큰을 앞뒤로 추가.
  # ex) Where have you been? → [[8331   86   30    5 1059    7 8332]]
  sentence = tf.expand_dims(
      START_TOKEN + tokenizer.encode(sentence) + END_TOKEN, axis=0)

  # 디코더의 현재까지의 예측한 출력 시퀀스가 지속적으로 저장되는 변수.
  # 처음에는 예측한 내용이 없음으로 시작 토큰만 별도 저장. ex) 8331
  output_sequence = tf.expand_dims(START_TOKEN, 0)

  # 디코더의 인퍼런스 단계
  for i in range(MAX_LENGTH):
    # 디코더는 최대 MAX_LENGTH의 길이만큼 다음 단어 예측을 반복합니다.
    predictions = model(inputs=[sentence, output_sequence], training=False)
    predictions = predictions[:, -1:, :]

    # 현재 예측한 단어의 정수
    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    # 만약 현재 예측한 단어가 종료 토큰이라면 for문을 종료
    if tf.equal(predicted_id, END_TOKEN[0]):
      break

    # 예측한 단어들은 지속적으로 output_sequence에 추가됩니다.
    # 이 output_sequence는 다시 디코더의 입력이 됩니다.
    output_sequence = tf.concat([output_sequence, predicted_id], axis=-1)

  return tf.squeeze(output_sequence, axis=0)

# %%
def sentence_generation(sentence):
  # 입력 문장에 대해서 디코더를 동작 시켜 예측된 정수 시퀀스를 리턴받습니다.
  prediction = decoder_inference(sentence)

  # 정수 시퀀스를 다시 텍스트 시퀀스로 변환합니다.
  predicted_sentence = tokenizer.decode(
      [i for i in prediction if i < tokenizer.vocab_size])

  print('입력 : {}'.format(sentence))
  print('출력 : {}'.format(predicted_sentence))

  return predicted_sentence

# %%
# 기존 데이터에 대해서 생성된 문장 확인 - dataframe에 저장, sample로 50개만 확인
generated_sentences = []
for i in range(50):
    generated_sentences.append(sentence_generation(train['Q'][i]))

# 기존 데이터에 컬럼 추가에서 같이 확인
train = train[:50]
train['generated_A'] = generated_sentences
# train.head(50)
# Out:
# 입력 : 12시 땡!
# 출력 : 무덤덤해졌다면 그럴 거예요 .
# 입력 : 1지망 학교 떨어졌어
# 출력 : 위로해 드립니다 .
# 입력 : 3박4일 놀러가고 싶다
# 출력 : 여행은 언제나 좋죠 .
# 입력 : 3박4일 정도 놀러가고 싶다
# 출력 : 여행은 언제나 좋죠 .
# 입력 : PPL 심하네
# 출력 : 눈살이 찌푸려지죠 .
# 입력 : SD카드 망가졌어
# 출력 : 다시 새로 사는 게 마음 편해요 .
# 입력 : SD카드 안돼
# 출력 : 다시 새로 사는 게 마음 편해요 .
# 입력 : SNS 맞팔 왜 안하지ㅠㅠ
# 출력 : 잘 모르고 있을 수도 있어요 .
# 입력 : SNS 시간낭비인 거 아는데 매일 하는 중
# 출력 : 시간을 정하고 해보세요 .
# 입력 : SNS 시간낭비인데 자꾸 보게됨
# 출력 : 시간을 정하고 해보세요 .
# 입력 : SNS보면 나만 빼고 다 행복해보여
# 출력 : 아예 보지 마세요 .
# 입력 : 가끔 궁금해
# 출력 : 그 사람도 그럴 거예요 .
# 입력 : 가끔 뭐하는지 궁금해
# 출력 : 그 사람도 그럴 거예요 .
# 입력 : 가끔은 혼자인게 좋다
# 출력 : 혼자를 즐기세요 .
# 입력 : 가난한 자의 설움
# 출력 : 앞모습을 볼 수가 없나봐요 .
# 입력 : 가만 있어도 땀난다
# 출력 : 땀을 식혀주세요 .
# 입력 : 가상화폐 쫄딱 망함
# 출력 : 어서 잊고 새출발 하세요 .
# 입력 : 가스불 켜고 나갔어
# 출력 : 빨리 집에 돌아가서 끄고 나오세요 .
# 입력 : 가스불 켜놓고 나온거 같아
# 출력 : 빨리 집에 돌아가서 끄고 나오세요 .
# 입력 : 가스비 너무 많이 나왔다.
# 출력 : 언젠간 잊혀지더라고요 .
# 입력 : 가스비 비싼데 감기 걸리겠어
# 출력 : 따뜻하게 사세요 !
# 입력 : 가스비 장난 아님
# 출력 : 다음 달에는 더 절약해봐요 .
# 입력 : 가장 확실한 건 뭘까?
# 출력 : 가장 확실한 시간은 오늘이에요 . 어제와 내일을 놓고 고민하느라 시간을 낭비하지 마세요 .
# 입력 : 가족 여행 가기로 했어
# 출력 : 온 가족이 모두 마음에 드는 곳으로 가보세요 .
# 입력 : 가족 여행 고고
# 출력 : 온 가족이 모두 마음에 드는 곳으로 가보세요 .
# 입력 : 가족 여행 어디로 가지?
# 출력 : 온 가족이 모두 마음에 드는 곳으로 가보세요 .
# 입력 : 가족 있어?
# 출력 : 저를 만들어 준 사람을 부모님 , 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 입력 : 가족관계 알려 줘
# 출력 : 저를 만들어 준 사람을 부모님 , 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 입력 : 가족끼리 여행간다.
# 출력 : 더 가까워질 기회가 되겠네요 .
# 입력 : 가족들 보고 싶어
# 출력 : 졸업 축하해요
# 입력 : 가족들이랑 서먹해
# 출력 : 다들 바빠서 이야기할 시간이 부족했나봐요 .
# 입력 : 가족들이랑 서먹해졌어
# 출력 : 온 가족이 모두 마음에 드는 곳으로 가보세요 .
# 입력 : 가족들이랑 어디 가지?
# 출력 : 온 가족이 모두 마음에 드는 곳으로 가보세요 .
# 입력 : 가족들이랑 여행 갈거야
# 출력 : 저도 다들 힘들죠 .
# 입력 : 가족여행 가야지
# 출력 : 더 가까워질 기회가 되겠네요 .
# 입력 : 가족이 누구야?
# 출력 : 사람 마다 다르겠지요 .
# 입력 : 가족이랑 여행 가려고
# 출력 : 좋은 생각이에요 .
# 입력 : 가족한테 스트레스 풀었어
# 출력 : 정말 후회할 습관이에요 .
# 입력 : 가출할까?
# 출력 : 무모한 결정을 내리지 마세요 .
# 입력 : 가출해도 갈 데가 없어
# 출력 : 좀 내려놔주는 건 어떨까요 .
# 입력 : 간만에 떨리니까 좋더라
# 출력 : 떨리는 감정은 그 자체로 소중해요 .
# 입력 : 간만에 쇼핑 중
# 출력 : 좋아하는 것도 괜찮을거 같아요 .
# 입력 : 간만에 휴식 중
# 출력 : 휴식도 필요하죠 .
# 입력 : 간식 뭐 먹을까
# 출력 : 단짠으로 두 개 사는게 진리죠 .
# 입력 : 간식 추천
# 출력 : 단짠으로 두 개 사는게 진리죠 .
# 입력 : 간장치킨 시켜야지
# 출력 : 맛있게 드세요 .
# 입력 : 간접흡연 싫어
# 출력 : 친구와 썸의 중간인 거 같아요 .
# 입력 : 갈까 말까 고민 돼
# 출력 : 직장 스트레스가 심한가봐요 .
# 입력 : 갈까 말까?
# 출력 : 가세요 .
# 입력 : 감 말랭이 먹고 싶다.
# 출력 : 맛있게 드세요 .
#                           Q                                                 A  \
# 0                    12시 땡!                                        하루가 또 가네요.
# 1               1지망 학교 떨어졌어                                         위로해 드립니다.
# 2              3박4일 놀러가고 싶다                                       여행은 언제나 좋죠.
# 3           3박4일 정도 놀러가고 싶다                                       여행은 언제나 좋죠.
# 4                   PPL 심하네                                        눈살이 찌푸려지죠.
# 5                 SD카드 망가졌어                                다시 새로 사는 게 마음 편해요.
# 6                   SD카드 안돼                                다시 새로 사는 게 마음 편해요.
# 7            SNS 맞팔 왜 안하지ㅠㅠ                                  잘 모르고 있을 수도 있어요.
# 8   SNS 시간낭비인 거 아는데 매일 하는 중                                     시간을 정하고 해보세요.
# 9         SNS 시간낭비인데 자꾸 보게됨                                     시간을 정하고 해보세요.
# 10      SNS보면 나만 빼고 다 행복해보여                                       자랑하는 자리니까요.
# 11                   가끔 궁금해                                     그 사람도 그럴 거예요.
# 12              가끔 뭐하는지 궁금해                                     그 사람도 그럴 거예요.
# 13              가끔은 혼자인게 좋다                                         혼자를 즐기세요.
# 14                가난한 자의 설움                                    돈은 다시 들어올 거예요.
# 15               가만 있어도 땀난다                                         땀을 식혀주세요.
# 16               가상화폐 쫄딱 망함                                    어서 잊고 새출발 하세요.
# 17               가스불 켜고 나갔어                               빨리 집에 돌아가서 끄고 나오세요.
# 18           가스불 켜놓고 나온거 같아                               빨리 집에 돌아가서 끄고 나오세요.
# 19           가스비 너무 많이 나왔다.                                   다음 달에는 더 절약해봐요.
# 20          가스비 비싼데 감기 걸리겠어                                         따뜻하게 사세요!
# 21                가스비 장난 아님                                   다음 달에는 더 절약해봐요.
# 22             가장 확실한 건 뭘까?  가장 확실한 시간은 오늘이에요. 어제와 내일을 놓고 고민하느라 시간을 낭비하지 마세요.
# 23             가족 여행 가기로 했어                         온 가족이 모두 마음에 드는 곳으로 가보세요.
# 24                 가족 여행 고고                         온 가족이 모두 마음에 드는 곳으로 가보세요.
# 25            가족 여행 어디로 가지?                         온 가족이 모두 마음에 드는 곳으로 가보세요.
# 26                   가족 있어?     저를 만들어 준 사람을 부모님, 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 27                가족관계 알려 줘     저를 만들어 준 사람을 부모님, 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 28               가족끼리 여행간다.                                  더 가까워질 기회가 되겠네요.
# 29                가족들 보고 싶어                                              저도요.
# 30                가족들이랑 서먹해                           다들 바빠서 이야기할 시간이 부족했나봐요.
# 31              가족들이랑 서먹해졌어                           다들 바빠서 이야기할 시간이 부족했나봐요.
# 32             가족들이랑 어디 가지?                         온 가족이 모두 마음에 드는 곳으로 가보세요.
# 33             가족들이랑 여행 갈거야                                         좋은 생각이에요.
# 34                 가족여행 가야지                                  더 가까워질 기회가 되겠네요.
# 35                 가족이 누구야?     저를 만들어 준 사람을 부모님, 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 36              가족이랑 여행 가려고                                         좋은 생각이에요.
# 37            가족한테 스트레스 풀었어                                     정말 후회할 습관이에요.
# 38                    가출할까?                                  무모한 결정을 내리지 마세요.
# 39             가출해도 갈 데가 없어                                 선생님이나 기관에 연락해보세요.
# 40             간만에 떨리니까 좋더라                               떨리는 감정은 그 자체로 소중해요.
# 41                 간만에 쇼핑 중                                         득템했길 바라요.
# 42                 간만에 휴식 중                                         휴식도 필요하죠.
# 43                 간식 뭐 먹을까                                 단짠으로 두 개 사는게 진리죠.
# 44                    간식 추천                                 단짠으로 두 개 사는게 진리죠.
# 45                간장치킨 시켜야지                                          맛있게 드세요.
# 46                  간접흡연 싫어                                           저도 싫어요.
# 47               갈까 말까 고민 돼                                              가세요.
# 48                   갈까 말까?                                              가세요.
# 49             감 말랭이 먹고 싶다.                                          맛있게 드세요.
#
#     label                                        generated_A
# 0       0                                   무덤덤해졌다면 그럴 거예요 .
# 1       0                                         위로해 드립니다 .
# 2       0                                       여행은 언제나 좋죠 .
# 3       0                                       여행은 언제나 좋죠 .
# 4       0                                        눈살이 찌푸려지죠 .
# 5       0                                다시 새로 사는 게 마음 편해요 .
# 6       0                                다시 새로 사는 게 마음 편해요 .
# 7       0                                  잘 모르고 있을 수도 있어요 .
# 8       0                                     시간을 정하고 해보세요 .
# 9       0                                     시간을 정하고 해보세요 .
# 10      0                                        아예 보지 마세요 .
# 11      0                                     그 사람도 그럴 거예요 .
# 12      0                                     그 사람도 그럴 거예요 .
# 13      0                                         혼자를 즐기세요 .
# 14      0                                   앞모습을 볼 수가 없나봐요 .
# 15      0                                         땀을 식혀주세요 .
# 16      0                                    어서 잊고 새출발 하세요 .
# 17      0                               빨리 집에 돌아가서 끄고 나오세요 .
# 18      0                               빨리 집에 돌아가서 끄고 나오세요 .
# 19      0                                      언젠간 잊혀지더라고요 .
# 20      0                                         따뜻하게 사세요 !
# 21      0                                   다음 달에는 더 절약해봐요 .
# 22      0  가장 확실한 시간은 오늘이에요 . 어제와 내일을 놓고 고민하느라 시간을 낭비하지 마...
# 23      0                         온 가족이 모두 마음에 드는 곳으로 가보세요 .
# 24      0                         온 가족이 모두 마음에 드는 곳으로 가보세요 .
# 25      0                         온 가족이 모두 마음에 드는 곳으로 가보세요 .
# 26      0     저를 만들어 준 사람을 부모님 , 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 27      0     저를 만들어 준 사람을 부모님 , 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 28      0                                  더 가까워질 기회가 되겠네요 .
# 29      0                                            졸업 축하해요
# 30      0                           다들 바빠서 이야기할 시간이 부족했나봐요 .
# 31      0                         온 가족이 모두 마음에 드는 곳으로 가보세요 .
# 32      0                         온 가족이 모두 마음에 드는 곳으로 가보세요 .
# 33      0                                        저도 다들 힘들죠 .
# 34      0                                  더 가까워질 기회가 되겠네요 .
# 35      0                                      사람 마다 다르겠지요 .
# 36      0                                         좋은 생각이에요 .
# 37      0                                     정말 후회할 습관이에요 .
# 38      0                                  무모한 결정을 내리지 마세요 .
# 39      0                                   좀 내려놔주는 건 어떨까요 .
# 40      0                               떨리는 감정은 그 자체로 소중해요 .
# 41      0                                 좋아하는 것도 괜찮을거 같아요 .
# 42      0                                         휴식도 필요하죠 .
# 43      0                                 단짠으로 두 개 사는게 진리죠 .
# 44      0                                 단짠으로 두 개 사는게 진리죠 .
# 45      0                                          맛있게 드세요 .
# 46      0                                 친구와 썸의 중간인 거 같아요 .
# 47      0                                   직장 스트레스가 심한가봐요 .
# 48      0                                              가세요 .
# 49      0                                          맛있게 드세요 .

# %%
# train 데이터에 대해서 BLEU 점수 계산
from nltk.translate.bleu_score import sentence_bleu

def bleu_score(reference, candidate):
    reference = reference.split()
    candidate = candidate.split()
    return sentence_bleu([reference], candidate)

bleu_scores = []
for i in range(50):
    reference = train['A'][i]
    candidate = train['generated_A'][i]
    bleu_scores.append(bleu_score(reference, candidate))

train['BLEU'] = bleu_scores
train.head(50)
# Out:
# /home/mjun/.conda/envs/pp/lib/python3.8/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/mjun/.conda/envs/pp/lib/python3.8/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /home/mjun/.conda/envs/pp/lib/python3.8/site-packages/nltk/translate/bleu_score.py:577: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
#                           Q                                                 A  \
# 0                    12시 땡!                                        하루가 또 가네요.
# 1               1지망 학교 떨어졌어                                         위로해 드립니다.
# 2              3박4일 놀러가고 싶다                                       여행은 언제나 좋죠.
# 3           3박4일 정도 놀러가고 싶다                                       여행은 언제나 좋죠.
# 4                   PPL 심하네                                        눈살이 찌푸려지죠.
# 5                 SD카드 망가졌어                                다시 새로 사는 게 마음 편해요.
# 6                   SD카드 안돼                                다시 새로 사는 게 마음 편해요.
# 7            SNS 맞팔 왜 안하지ㅠㅠ                                  잘 모르고 있을 수도 있어요.
# 8   SNS 시간낭비인 거 아는데 매일 하는 중                                     시간을 정하고 해보세요.
# 9         SNS 시간낭비인데 자꾸 보게됨                                     시간을 정하고 해보세요.
# 10      SNS보면 나만 빼고 다 행복해보여                                       자랑하는 자리니까요.
# 11                   가끔 궁금해                                     그 사람도 그럴 거예요.
# 12              가끔 뭐하는지 궁금해                                     그 사람도 그럴 거예요.
# 13              가끔은 혼자인게 좋다                                         혼자를 즐기세요.
# 14                가난한 자의 설움                                    돈은 다시 들어올 거예요.
# 15               가만 있어도 땀난다                                         땀을 식혀주세요.
# 16               가상화폐 쫄딱 망함                                    어서 잊고 새출발 하세요.
# 17               가스불 켜고 나갔어                               빨리 집에 돌아가서 끄고 나오세요.
# 18           가스불 켜놓고 나온거 같아                               빨리 집에 돌아가서 끄고 나오세요.
# 19           가스비 너무 많이 나왔다.                                   다음 달에는 더 절약해봐요.
# 20          가스비 비싼데 감기 걸리겠어                                         따뜻하게 사세요!
# 21                가스비 장난 아님                                   다음 달에는 더 절약해봐요.
# 22             가장 확실한 건 뭘까?  가장 확실한 시간은 오늘이에요. 어제와 내일을 놓고 고민하느라 시간을 낭비하지 마세요.
# 23             가족 여행 가기로 했어                         온 가족이 모두 마음에 드는 곳으로 가보세요.
# 24                 가족 여행 고고                         온 가족이 모두 마음에 드는 곳으로 가보세요.
# 25            가족 여행 어디로 가지?                         온 가족이 모두 마음에 드는 곳으로 가보세요.
# 26                   가족 있어?     저를 만들어 준 사람을 부모님, 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 27                가족관계 알려 줘     저를 만들어 준 사람을 부모님, 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 28               가족끼리 여행간다.                                  더 가까워질 기회가 되겠네요.
# 29                가족들 보고 싶어                                              저도요.
# 30                가족들이랑 서먹해                           다들 바빠서 이야기할 시간이 부족했나봐요.
# 31              가족들이랑 서먹해졌어                           다들 바빠서 이야기할 시간이 부족했나봐요.
# 32             가족들이랑 어디 가지?                         온 가족이 모두 마음에 드는 곳으로 가보세요.
# 33             가족들이랑 여행 갈거야                                         좋은 생각이에요.
# 34                 가족여행 가야지                                  더 가까워질 기회가 되겠네요.
# 35                 가족이 누구야?     저를 만들어 준 사람을 부모님, 저랑 이야기해 주는 사람을 친구로 생각하고 있어요
# 36              가족이랑 여행 가려고                                         좋은 생각이에요.
# 37            가족한테 스트레스 풀었어                                     정말 후회할 습관이에요.
# 38                    가출할까?                                  무모한 결정을 내리지 마세요.
# 39             가출해도 갈 데가 없어                                 선생님이나 기관에 연락해보세요.
# 40             간만에 떨리니까 좋더라                               떨리는 감정은 그 자체로 소중해요.
# 41                 간만에 쇼핑 중                                         득템했길 바라요.
# 42                 간만에 휴식 중                                         휴식도 필요하죠.
# 43                 간식 뭐 먹을까                                 단짠으로 두 개 사는게 진리죠.
# 44                    간식 추천                                 단짠으로 두 개 사는게 진리죠.
# 45                간장치킨 시켜야지                                          맛있게 드세요.
# 46                  간접흡연 싫어                                           저도 싫어요.
# 47               갈까 말까 고민 돼                                              가세요.
# 48                   갈까 말까?                                              가세요.
# 49             감 말랭이 먹고 싶다.                                          맛있게 드세요.
#
#     label                                        generated_A           BLEU
# 0       0                                   무덤덤해졌다면 그럴 거예요 .   0.000000e+00
# 1       0                                         위로해 드립니다 .  1.384293e-231
# 2       0                                       여행은 언제나 좋죠 .  9.530911e-155
# 3       0                                       여행은 언제나 좋죠 .  9.530911e-155
# 4       0                                        눈살이 찌푸려지죠 .  1.384293e-231
# 5       0                                다시 새로 사는 게 마음 편해요 .   6.147882e-01
# 6       0                                다시 새로 사는 게 마음 편해요 .   6.147882e-01
# 7       0                                  잘 모르고 있을 수도 있어요 .   5.081327e-01
# 8       0                                     시간을 정하고 해보세요 .  9.530911e-155
# 9       0                                     시간을 정하고 해보세요 .  9.530911e-155
# 10      0                                        아예 보지 마세요 .   0.000000e+00
# 11      0                                     그 사람도 그럴 거예요 .   6.868092e-78
# 12      0                                     그 사람도 그럴 거예요 .   6.868092e-78
# 13      0                                         혼자를 즐기세요 .  1.384293e-231
# 14      0                                   앞모습을 볼 수가 없나봐요 .   0.000000e+00
# 15      0                                         땀을 식혀주세요 .  1.384293e-231
# 16      0                                    어서 잊고 새출발 하세요 .   6.868092e-78
# 17      0                               빨리 집에 돌아가서 끄고 나오세요 .   5.081327e-01
# 18      0                               빨리 집에 돌아가서 끄고 나오세요 .   5.081327e-01
# 19      0                                      언젠간 잊혀지더라고요 .   0.000000e+00
# 20      0                                         따뜻하게 사세요 !  1.384293e-231
# 21      0                                   다음 달에는 더 절약해봐요 .   6.868092e-78
# 22      0  가장 확실한 시간은 오늘이에요 . 어제와 내일을 놓고 고민하느라 시간을 낭비하지 마...   4.844273e-01
# 23      0                         온 가족이 모두 마음에 드는 곳으로 가보세요 .   6.803749e-01
# 24      0                         온 가족이 모두 마음에 드는 곳으로 가보세요 .   6.803749e-01
# 25      0                         온 가족이 모두 마음에 드는 곳으로 가보세요 .   6.803749e-01
# 26      0     저를 만들어 준 사람을 부모님 , 저랑 이야기해 주는 사람을 친구로 생각하고 있어요   6.703421e-01
# 27      0     저를 만들어 준 사람을 부모님 , 저랑 이야기해 주는 사람을 친구로 생각하고 있어요   6.703421e-01
# 28      0                                  더 가까워질 기회가 되겠네요 .   6.868092e-78
# 29      0                                            졸업 축하해요   0.000000e+00
# 30      0                           다들 바빠서 이야기할 시간이 부족했나봐요 .   5.081327e-01
# 31      0                         온 가족이 모두 마음에 드는 곳으로 가보세요 .   0.000000e+00
# 32      0                         온 가족이 모두 마음에 드는 곳으로 가보세요 .   6.803749e-01
# 33      0                                        저도 다들 힘들죠 .   0.000000e+00
# 34      0                                  더 가까워질 기회가 되겠네요 .   6.868092e-78
# 35      0                                      사람 마다 다르겠지요 .   0.000000e+00
# 36      0                                         좋은 생각이에요 .  1.384293e-231
# 37      0                                     정말 후회할 습관이에요 .  9.530911e-155
# 38      0                                  무모한 결정을 내리지 마세요 .   6.868092e-78
# 39      0                                   좀 내려놔주는 건 어떨까요 .   0.000000e+00
# 40      0                               떨리는 감정은 그 자체로 소중해요 .   5.081327e-01
# 41      0                                 좋아하는 것도 괜찮을거 같아요 .   0.000000e+00
# 42      0                                         휴식도 필요하죠 .  1.384293e-231
# 43      0                                 단짠으로 두 개 사는게 진리죠 .   5.081327e-01
# 44      0                                 단짠으로 두 개 사는게 진리죠 .   5.081327e-01
# 45      0                                          맛있게 드세요 .  1.384293e-231
# 46      0                                 친구와 썸의 중간인 거 같아요 .   0.000000e+00
# 47      0                                   직장 스트레스가 심한가봐요 .   0.000000e+00
# 48      0                                              가세요 .   0.000000e+00
# 49      0                                          맛있게 드세요 .  1.384293e-231

# %%
def evaluate(sentence):
  # 입력 문장에 대한 전처리
  sentence = preprocess_sentence(sentence)

  # 입력 문장에 시작 토큰과 종료 토큰을 추가
  sentence = tf.expand_dims(
      START_TOKEN + tokenizer.encode(sentence) + END_TOKEN, axis=0)

  output = tf.expand_dims(START_TOKEN, 0)

  # 디코더의 예측 시작
  for i in range(MAX_LENGTH):
    predictions = model(inputs=[sentence, output], training=False)

    # 현재 시점의 예측 단어를 받아온다.
    predictions = predictions[:, -1:, :]
    predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int32)

    # 만약 현재 시점의 예측 단어가 종료 토큰이라면 예측을 중단
    if tf.equal(predicted_id, END_TOKEN[0]):
      break

    # 현재 시점의 예측 단어를 output(출력)에 연결한다.
    # output은 for문의 다음 루프에서 디코더의 입력이 된다.
    output = tf.concat([output, predicted_id], axis=-1)

  # 단어 예측이 모두 끝났다면 output을 리턴.
  return tf.squeeze(output, axis=0)

# %%
def predict(sentence):
  prediction = evaluate(sentence)

  # prediction == 디코더가 리턴한 챗봇의 대답에 해당하는 정수 시퀀스
  # tokenizer.decode()를 통해 정수 시퀀스를 문자열로 디코딩.
  predicted_sentence = tokenizer.decode(
      [i for i in prediction if i < tokenizer.vocab_size])

  print('Input: {}'.format(sentence))
  print('Output: {}'.format(predicted_sentence))

  return predicted_sentence

# %%
output = predict("영화 볼래?")
# Out:
# Input: 영화 볼래?
# Output: 한동안은 힘들지도 몰라요 .

# %%
output = predict("고민이 있어")
# Out:
# Input: 고민이 있어
# Output: 생각을 종이에 끄젹여여 보는게 도움이 될 수도 있어요 .

# %%
output = predict("게임하자")
# Out:
# Input: 게임하자
# Output: 자신과 서로를 존중하고 마음을 표현해보세요 .

# %%
output = predict("가장 확실한 건 뭘까?")
# Out:
# Input: 가장 확실한 건 뭘까?
# Output: 가장 확실한 시간은 오늘이에요 . 어제와 내일을 놓고 고민하느라 시간을 낭비하지 마세요 .

# %% [markdown]
# ## 회고

# %% [markdown]
# - 작은 모델일 큰 모델이 보다 상대적으로 좋은 성능?(사실 둘 다 좋은거 같진 않음)을 보임
#     - 내가 생각하는 이유 : 둘다 우선 val_loss를 볼 때 과적합 현상을 보이고 있음
#     - 학습 데이터셋 자체가 너무 단순하고 적다. eda를 해봐도 평균 길이가 13, 젤 긴 시퀀스가 57임
#     - 학습을 하기에는 데이터 다양성 복잡성의 불균형이 있는 듯 하다.
#     - BLUE SCORE를 봤을때도 점수라도 측정가능..ㅎ(그래도 납득이 될만한 답변을 줌)
#     - ai hub에 한국어 챗봇 데이터를 정제해서 활용하면 현 아키텍쳐에서는 그래도 좀 더 좋은? 정성적인 평가가 가능하지 않을까?.. 추후 실험을 해봐야 할거같다
